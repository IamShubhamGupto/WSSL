# %% [markdown]
# <a href="https://colab.research.google.com/github/IamShubhamGupto/WSSL-Weighted-Self-Supervised-Learning-for-Image-Inpainting/blob/main/notebook/P2R3/Rotation_Saturation_Pretext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/seshuad/IMagenet
! ls 'IMagenet/tiny-imagenet-200/'
# Out:
# Cloning into 'IMagenet'...
# remote: Enumerating objects: 120594, done.
# remote: Total 120594 (delta 0), reused 0 (delta 0), pack-reused 120594
# Receiving objects: 100% (120594/120594), 212.68 MiB | 24.05 MiB/s, done.
# Resolving deltas: 100% (1115/1115), done.
# Checking out files: 100% (120206/120206), done.
# test  train  val  wnids.txt  words.txt

# %%
import time
import scipy.ndimage as nd
import scipy.misc
import cv2
import numpy as np
import os
import glob
import gc
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import to_categorical
from PIL import Image, ImageEnhance
from random import randint
import pandas as pd

from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D, concatenate
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from google.colab.patches import cv2_imshow
import plotly.graph_objects as go
# %matplotlib inline

# %%
import random as rn
np.random.seed(4321)
rn.seed(4321)
tf.random.set_seed(4321)

# %% [markdown]
# Extract test and training data from Tiny ImageNet DataSet

# %%
# path = '/content/drive/MyDrive/saved_images'

path = 'IMagenet/tiny-imagenet-200/'

def get_id_dictionary():
    id_dict = {}
    for i, line in enumerate(open( path + 'wnids.txt', 'r')):
        id_dict[line.replace('\n', '')] = i
    return id_dict
  
def get_class_to_id_dict():
    id_dict = get_id_dictionary()
    all_classes = {}
    result = {}
    for i, line in enumerate(open( path + 'words.txt', 'r')):
        n_id, word = line.split('\t')[:2]
        all_classes[n_id] = word
    for key, value in id_dict.items():
        result[value] = (key, all_classes[key])      
    return result

def get_data(id_dict):
    print('starting loading data')
    train_data, test_data = [], []
    train_labels, test_labels = [], []
    t = time.time()
    for key, value in id_dict.items():
        train_data += [cv2.imread( path + 'train/{}/images/{}_{}.JPEG'.format(key, key, str(i))) for i in range(500)]
        train_labels_ = np.array([[0]*200]*500)
        train_labels_[:, value] = 1
        train_labels += train_labels_.tolist()

    for line in open( path + 'val/val_annotations.txt'):
        img_name, class_id = line.split('\t')[:2]
        test_data.append(cv2.imread( path + 'val/images/{}'.format(img_name)))
        test_labels_ = np.array([[0]*200])
        test_labels_[0, id_dict[class_id]] = 1
        test_labels += test_labels_.tolist()

    print('finished loading data, in {} seconds'.format(time.time() - t))
    return np.array(train_data), np.array(train_labels), np.array(test_data), np.array(test_labels)

# %%
def rotate_image():
  return randint(0,3)
  
def sat_image():
  return randint(0,3)

# %%
IM_WIDTH = IM_HEIGHT = 64
TRAIN_TEST_SPLIT = 0.8
dataset_dict = {
    'rotation_id': {
        0: '0', 
        1: '90', 
        2: '180', 
        3: '270', 
    },
    'sat_id': {
        0: '0.0',
        1: '0.25',
        2: '0.75',
        3: '1'
    }
}
dataset_dict['rotation_alias'] = dict((r, i) for i, r in dataset_dict['rotation_id'].items())
dataset_dict['sat_alias'] = dict((s, i) for i, s in dataset_dict['sat_id'].items())

# %%
def prepare_dataset(dataset, ext='JPEG'):
    def generate_rotate_sharp():
      res_rot = rotate_image()
      res_sharp = sat_image()
      return [res_rot, res_sharp]

    id_dict = get_id_dictionary()
    files = []
    for key in id_dict.keys():
      files += [dataset + 'train/{}/images/{}_{}.JPEG'.format(key, key, str(i)) for i in range(500)]
    records = []
    files += glob.glob(dataset + 'val/images/*')
    for _ in files:
        info = generate_rotate_sharp()
        records.append(info)
        
    df = pd.DataFrame(records)
    df['image'] = files
    df.columns = ['rotation_id', 'sat_id', 'image']
    df = df.dropna()
    
    return df
df = prepare_dataset(path)
df.head()
# Out:
#    rotation_id  sat_id                                              image
# 0            2       0  IMagenet/tiny-imagenet-200/train/n02124075/ima...
# 1            2       3  IMagenet/tiny-imagenet-200/train/n02124075/ima...
# 2            2       3  IMagenet/tiny-imagenet-200/train/n02124075/ima...
# 3            2       2  IMagenet/tiny-imagenet-200/train/n02124075/ima...
# 4            2       3  IMagenet/tiny-imagenet-200/train/n02124075/ima...

# %%
def plot_distribution(pd_series, key):
    labels = pd_series.value_counts().index.tolist()
    counts = pd_series.value_counts().values.tolist()
    labels = list(map(lambda id: dataset_dict[key][id], labels))

    pie_plot = go.Pie(labels=labels, values=counts, hole=.3)
    fig = go.Figure(data=[pie_plot])
    fig.update_layout(title_text='Distribution for %s' % pd_series.name)
    
    fig.show()

# %%
plot_distribution(df['rotation_id'], 'rotation_id')
plot_distribution(df['sat_id'], 'sat_id')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ab78342e-ad6c-4fc6-bae8-74cd40dff6ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ab78342e-ad6c-4fc6-bae8-74cd40dff6ba")) {
#                     Plotly.newPlot(
#                         'ab78342e-ad6c-4fc6-bae8-74cd40dff6ba',
#                         [{"hole": 0.3, "labels": ["0", "270", "90", "180"], "type": "pie", "values": [27715, 27474, 27439, 27372]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ea8a793a-64c8-4d44-82ce-20a18544f3fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ea8a793a-64c8-4d44-82ce-20a18544f3fb")) {
#                     Plotly.newPlot(
#                         'ea8a793a-64c8-4d44-82ce-20a18544f3fb',
#                         [{"hole": 0.3, "labels": ["0.25", "0.75", "0.0", "1"], "type": "pie", "values": [27654, 27566, 27533, 27247]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
class ImgDataGenerator():
    """
    Data generator for the Tiny imagenet dataset. This class should be used when training our Keras multi-output model.
    """
    def __init__(self, df):
        self.df = df
        
    def generate_split_indexes(self):
        self.df = self.df.sample(frac=1).reset_index(drop=True)
        train_up_to = int(len(self.df) * TRAIN_TEST_SPLIT)
        train_val_idx = self.df.tail(train_up_to)

        test_idx = self.df.head(len(self.df) - train_up_to)
        train_up_to = int(train_up_to * TRAIN_TEST_SPLIT)
        train_val_idx = train_val_idx.sample(frac=1).reset_index(drop=True)

        train_idx, valid_idx = train_val_idx.tail(train_up_to), train_val_idx.head(len(train_val_idx) - train_up_to)
        return train_idx, valid_idx, test_idx
    
    def preprocess_image(self, rotate: int, sat: int, img_path):
        """
        Used to perform some minor preprocessing on the image before inputting into the network.
        """
        im_cv = cv2.imread(img_path)
        im = cv2.cvtColor(im_cv, cv2.COLOR_BGR2RGB)
        
        if rotate == 1:
          im = cv2.rotate(im, cv2.cv2.ROTATE_90_CLOCKWISE)
        elif rotate == 2:  
          im = cv2.rotate(im, cv2.ROTATE_180)
        elif rotate >= 3:
          im = cv2.rotate(im, cv2.ROTATE_90_COUNTERCLOCKWISE)

        enhancer = ImageEnhance.Color(Image.fromarray(im))
        if sat == 0:
          sat = 0.0
        elif sat == 1:
          sat = 0.25
        elif sat == 2:  
          sat = 0.75
        elif sat >= 3:
          sat = 1.0
        
        out = np.array(enhancer.enhance(sat))
        # print(out.shape)
        out = out / 255.0

        # img = Image.fromarray(out, 'RGB')
        # img.save('my.png')
        # img.show()
        
        return out
        
    def generate_images(self, image_idx, is_training, batch_size=16):
        """
        Used to generate a batch with images when training/testing/validating our Keras model.
        """
        
        # arrays to store our batched data
        images, rotations, sats = [], [], []
        while True:
            for idx in range(len(image_idx)):
                row = image_idx.iloc[idx]
                
                rotation = row['rotation_id']
                sat = row['sat_id']
                
                im = self.preprocess_image(rotation, sat, row['image'])
                
                cat_rot = to_categorical(rotation, 4)
                cat_sat = to_categorical(sat, 4)
                rotations.append(cat_rot)
                sats.append(cat_sat)
                # print("rotation = ",rotation,"cat_rot = ",cat_rot)
                # print("sharpness = ",sharpness,"cat_sharp = ",cat_sharp)
                images.append(im)
                
                # yielding condition
                if len(images) >= batch_size:
                    yield np.array(images), [np.array(rotations), np.array(sats)]
                    images, rotations, sats = [], [], []
                    
            if not is_training:
                break
                
data_generator = ImgDataGenerator(df)
train_idx, valid_idx, test_idx = data_generator.generate_split_indexes()

# %%
print(train_idx.shape, valid_idx.shape, test_idx.shape)
# Out:
# (70400, 3) (17600, 3) (22000, 3)

# %%
DEBUG = 0
if DEBUG:
  data_gen = data_generator.generate_images(test_idx, is_training=False, batch_size=8)
  # images = data_gen[0]
  for i,data in enumerate(data_gen):
    images, outputs = data
    print(len(images))
    for j, image in enumerate(images):
      image *= 255.0
      print("rotation ",outputs[0][j])
      print("saturation ",outputs[1][j])
      cv2_imshow(image)
    break

# %%
kernel = (3,3)
pool = (2,2)
upstride = (2,2)
activation = 'relu'
class inpaintingModel:
  def build_encoder(self, inputs):
    # inputs = keras.layers.Input(input_size)
    conv1, pool1 = self.__ConvBlock(64, kernel, pool, activation, 'same', inputs) 
    conv2, pool2 = self.__ConvBlock(128, kernel, pool, activation, 'same', pool1)
    conv3, pool3 = self.__ConvBlock(256, kernel, pool, activation, 'same', pool2) 
    conv4, pool4 = self.__ConvBlock(512, kernel, pool, activation, 'same', pool3) 
    conv5, pool5 = self.__ConvBlock(1024, kernel, pool, activation, 'same', pool4)

    return conv1, conv2, conv3, conv4, conv5, pool5

  def build_decoder(self, conv1, conv2, conv3, conv4, conv5, pool_layer):
    conv6, up7 = self.__UpConvBlock(2048, 1024, kernel, pool, upstride, activation, 'same', pool_layer, conv5)
    conv7, up8 = self.__UpConvBlock(1024, 512, kernel, pool, upstride, activation, 'same', up7, conv4)
    conv8, up9 = self.__UpConvBlock(512, 256, kernel, pool, upstride, activation, 'same', up8, conv3)
    conv9, up10 = self.__UpConvBlock(256, 128, kernel, pool, upstride, activation, 'same', up9, conv2)
    conv10, up11 = self.__UpConvBlock(128, 64, kernel, pool, upstride, activation, 'same', up10, conv1)

    conv11 = self.__ConvBlock(32, kernel, pool, activation, 'same', up11, False)
    
    outputs = keras.layers.Conv2D(3, kernel, activation='sigmoid', padding='same')(conv11)

    return outputs
  '''
  Build UNET like model for image inpaining task.
  '''
  def prepare_model(self, input_size=(64,64,3)):
    inputs = keras.layers.Input(input_size)
    conv1, conv2, conv3, conv4, conv5, pool_layer = self.build_encoder(inputs)
    outputs = self.build_decoder(conv1, conv2, conv3, conv4, conv5, pool_layer)
    # conv1, pool1 = self.__ConvBlock(64, kernel, pool, activation, 'same', inputs) 
    # conv2, pool2 = self.__ConvBlock(128, kernel, pool, activation, 'same', pool1)
    # conv3, pool3 = self.__ConvBlock(256, kernel, pool, activation, 'same', pool2) 
    # conv4, pool4 = self.__ConvBlock(512, kernel, pool, activation, 'same', pool3) 
    # conv5, pool5 = self.__ConvBlock(1024, kernel, pool, activation, 'same', pool4)
     

    # conv6, up7 = self.__UpConvBlock(2048, 1024, kernel, pool, upstride, activation, 'same', pool5, conv5)
    # conv7, up8 = self.__UpConvBlock(1024, 512, kernel, pool, upstride, activation, 'same', up7, conv4)
    # conv8, up9 = self.__UpConvBlock(512, 256, kernel, pool, upstride, activation, 'same', up8, conv3)
    # conv9, up10 = self.__UpConvBlock(256, 128, kernel, pool, upstride, activation, 'same', up9, conv2)
    # conv10, up11 = self.__UpConvBlock(128, 64, kernel, pool, upstride, activation, 'same', up10, conv1)

    # conv11 = self.__ConvBlock(64, kernel, pool, activation, 'same', up11, False)
    
    # outputs = keras.layers.Conv2D(3, kernel, activation='sigmoid', padding='same')(conv11)
    # inpur
    return keras.models.Model(inputs=[inputs], outputs=[outputs])  

  def __ConvBlock(self, filters, kernel_size, pool_size, activation, padding, connecting_layer, pool_layer=True):
    conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(connecting_layer)
    conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(conv)
    if pool_layer:
      pool = keras.layers.MaxPooling2D(pool_size)(conv)
      return conv, pool
    else:
      return conv

  def __UpConvBlock(self, filters, up_filters, kernel_size, up_kernel, up_stride, activation, padding, connecting_layer, shared_layer):
    conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(connecting_layer)
    conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(conv)
    up = keras.layers.Conv2DTranspose(filters=up_filters, kernel_size=up_kernel, strides=up_stride, padding=padding)(conv)
    up = keras.layers.concatenate([up, shared_layer], axis=3)

    return conv, up

# %%
class pretextModel:
  def assemble_head_branch(self,  pool_layer, name):
    x = Flatten()(pool_layer)
    # changed
    x = Dense(512)(x)
    # changed
    # x = BatchNormalization()(x)
    x = Activation("relu")(x)
        
    # x = BatchNormalization()(x)
    # changed
    x = Dropout(0.4)(x)
    # x = Dense(2048, 
    #           kernel_regularizer=tf.keras.regularizers.l1_l2(l1=1e-5, l2=1e-4),
    #           bias_regularizer=tf.keras.regularizers.l2(1e-4),
    #           activity_regularizer=tf.keras.regularizers.l2(1e-5))(x)
    # changed
    x = Dense(512)(x)
    # changed
    # x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # x = BatchNormalization()(x)
    # changed
    x = Dropout(0.4)(x)
    x = Dense(4)(x)
    x = Activation("softmax", name=name)(x)
    return x

  def assemble_pretext_model(self):
    inputs = keras.layers.Input((64,64,3))
    conv1, conv2, conv3, conv4, conv5, pool_layer = inpaintingModel().build_encoder(inputs) 
    rotation_branch = self.assemble_head_branch(pool_layer, "rotation_output")
    saturation_branch = self.assemble_head_branch(pool_layer, "saturation_output")
    model = Model(inputs=inputs,
                  outputs = [rotation_branch, saturation_branch],
                  name="pretext_net")
    return model

# %%
from tensorflow import keras

# %%
keras.backend.clear_session()
p_model = pretextModel().assemble_pretext_model()

# %%
tf.keras.utils.plot_model(p_model, show_shapes=True, dpi=76, to_file='p_model_v1.png')

# %%
p_model.summary()
# Out:
# Model: "pretext_net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 256)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 512)    2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 1024)   4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 1024)   9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 1024)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         8390656     flatten[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         8390656     flatten_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2048)         8192        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2048)         8192        dense_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 2048)         0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 2048)         0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           activation[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2048)         0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     dropout[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         2098176     dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1024)         4096        dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1024)         4096        dense_4[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1024)         0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1024)         0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024)         0           activation_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4)            4100        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            4100        dropout_3[0][0]
# __________________________________________________________________________________________________
# rotation_output (Activation)    (None, 4)            0           dense_2[0][0]
# __________________________________________________________________________________________________
# saturation_output (Activation)  (None, 4)            0           dense_5[0][0]
# ==================================================================================================
# Total params: 39,853,640
# Trainable params: 39,841,352
# Non-trainable params: 12,288
# __________________________________________________________________________________________________

# %%
init_lr = 1e-4
epochs = 50
opt = Adam(learning_rate=init_lr, amsgrad=False)
p_model.compile(optimizer=opt, 
              loss={
                  'rotation_output': 'categorical_crossentropy', 
                  'saturation_output': 'categorical_crossentropy'},
              
              loss_weights={
                  'rotation_output': 0.6, 
                  'saturation_output': 0.4},
              metrics={
                  'rotation_output': 'accuracy',
                  'saturation_output': 'accuracy'})

# %%
import os
os.mkdir('p_model_checkpoint')
os.mkdir('d_model_checkpoint')

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
checkpoint = ModelCheckpoint("p_model_checkpoint/", monitor='val_loss')
batch_size = 256
valid_batch_size = 256
train_gen = data_generator.generate_images(train_idx, is_training=True, batch_size=batch_size)
valid_gen = data_generator.generate_images(valid_idx, is_training=True, batch_size=valid_batch_size)
callbacks = [early_stopping, checkpoint]
history = p_model.fit(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=epochs,
                    callbacks=callbacks,
                    # class_weight=dict(
                    #     rotation_output = rots_dict,
                    #     sharpness_output = sharps_dict
                    # ), 
                    # use_multiprocessing=True,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size
                    )
# Out:
# Epoch 1/100
# 275/275 [==============================] - 279s 853ms/step - loss: 1.3909 - rotation_output_loss: 1.4293 - saturation_output_loss: 1.3525 - rotation_output_accuracy: 0.3284 - saturation_output_accuracy: 0.3591 - val_loss: 1.3808 - val_rotation_output_loss: 1.3840 - val_saturation_output_loss: 1.3776 - val_rotation_output_accuracy: 0.2853 - val_saturation_output_accuracy: 0.3184
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 2/100
# 275/275 [==============================] - 231s 841ms/step - loss: 1.2132 - rotation_output_loss: 1.3342 - saturation_output_loss: 1.0922 - rotation_output_accuracy: 0.3704 - saturation_output_accuracy: 0.4912 - val_loss: 1.2808 - val_rotation_output_loss: 1.3515 - val_saturation_output_loss: 1.2102 - val_rotation_output_accuracy: 0.4020 - val_saturation_output_accuracy: 0.4713
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 3/100
# 275/275 [==============================] - 232s 844ms/step - loss: 1.1308 - rotation_output_loss: 1.3090 - saturation_output_loss: 0.9526 - rotation_output_accuracy: 0.3886 - saturation_output_accuracy: 0.5680 - val_loss: 1.0761 - val_rotation_output_loss: 1.2743 - val_saturation_output_loss: 0.8778 - val_rotation_output_accuracy: 0.4136 - val_saturation_output_accuracy: 0.6143
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 4/100
# 275/275 [==============================] - 232s 846ms/step - loss: 1.0746 - rotation_output_loss: 1.2917 - saturation_output_loss: 0.8576 - rotation_output_accuracy: 0.4002 - saturation_output_accuracy: 0.6107 - val_loss: 1.0269 - val_rotation_output_loss: 1.2554 - val_saturation_output_loss: 0.7983 - val_rotation_output_accuracy: 0.4254 - val_saturation_output_accuracy: 0.6324
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 5/100
# 275/275 [==============================] - 231s 839ms/step - loss: 1.0372 - rotation_output_loss: 1.2775 - saturation_output_loss: 0.7969 - rotation_output_accuracy: 0.4091 - saturation_output_accuracy: 0.6372 - val_loss: 0.9987 - val_rotation_output_loss: 1.2430 - val_saturation_output_loss: 0.7544 - val_rotation_output_accuracy: 0.4303 - val_saturation_output_accuracy: 0.6558
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 6/100
# 275/275 [==============================] - 229s 834ms/step - loss: 1.0086 - rotation_output_loss: 1.2595 - saturation_output_loss: 0.7576 - rotation_output_accuracy: 0.4218 - saturation_output_accuracy: 0.6538 - val_loss: 0.9812 - val_rotation_output_loss: 1.2395 - val_saturation_output_loss: 0.7229 - val_rotation_output_accuracy: 0.4260 - val_saturation_output_accuracy: 0.6705
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 7/100
# 275/275 [==============================] - 229s 834ms/step - loss: 0.9884 - rotation_output_loss: 1.2488 - saturation_output_loss: 0.7281 - rotation_output_accuracy: 0.4305 - saturation_output_accuracy: 0.6683 - val_loss: 0.9714 - val_rotation_output_loss: 1.2271 - val_saturation_output_loss: 0.7156 - val_rotation_output_accuracy: 0.4393 - val_saturation_output_accuracy: 0.6739
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 8/100
# 275/275 [==============================] - 227s 825ms/step - loss: 0.9699 - rotation_output_loss: 1.2350 - saturation_output_loss: 0.7047 - rotation_output_accuracy: 0.4395 - saturation_output_accuracy: 0.6774 - val_loss: 0.9517 - val_rotation_output_loss: 1.2220 - val_saturation_output_loss: 0.6814 - val_rotation_output_accuracy: 0.4447 - val_saturation_output_accuracy: 0.6884
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 9/100
# 275/275 [==============================] - 226s 823ms/step - loss: 0.9549 - rotation_output_loss: 1.2252 - saturation_output_loss: 0.6845 - rotation_output_accuracy: 0.4479 - saturation_output_accuracy: 0.6866 - val_loss: 0.9536 - val_rotation_output_loss: 1.2246 - val_saturation_output_loss: 0.6825 - val_rotation_output_accuracy: 0.4407 - val_saturation_output_accuracy: 0.6882
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 10/100
# 275/275 [==============================] - 229s 835ms/step - loss: 0.9413 - rotation_output_loss: 1.2120 - saturation_output_loss: 0.6706 - rotation_output_accuracy: 0.4542 - saturation_output_accuracy: 0.6927 - val_loss: 0.9390 - val_rotation_output_loss: 1.2045 - val_saturation_output_loss: 0.6734 - val_rotation_output_accuracy: 0.4586 - val_saturation_output_accuracy: 0.6923
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 11/100
# 275/275 [==============================] - 230s 838ms/step - loss: 0.9285 - rotation_output_loss: 1.2033 - saturation_output_loss: 0.6536 - rotation_output_accuracy: 0.4630 - saturation_output_accuracy: 0.7023 - val_loss: 0.9279 - val_rotation_output_loss: 1.2065 - val_saturation_output_loss: 0.6493 - val_rotation_output_accuracy: 0.4561 - val_saturation_output_accuracy: 0.7036
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 12/100
# 275/275 [==============================] - 231s 839ms/step - loss: 0.9180 - rotation_output_loss: 1.1918 - saturation_output_loss: 0.6442 - rotation_output_accuracy: 0.4702 - saturation_output_accuracy: 0.7048 - val_loss: 0.9201 - val_rotation_output_loss: 1.1954 - val_saturation_output_loss: 0.6449 - val_rotation_output_accuracy: 0.4655 - val_saturation_output_accuracy: 0.7062
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 13/100
# 275/275 [==============================] - 227s 827ms/step - loss: 0.9066 - rotation_output_loss: 1.1824 - saturation_output_loss: 0.6307 - rotation_output_accuracy: 0.4760 - saturation_output_accuracy: 0.7125 - val_loss: 0.9249 - val_rotation_output_loss: 1.1976 - val_saturation_output_loss: 0.6522 - val_rotation_output_accuracy: 0.4602 - val_saturation_output_accuracy: 0.7028
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 14/100
# 275/275 [==============================] - 227s 828ms/step - loss: 0.8952 - rotation_output_loss: 1.1696 - saturation_output_loss: 0.6207 - rotation_output_accuracy: 0.4838 - saturation_output_accuracy: 0.7161 - val_loss: 0.9110 - val_rotation_output_loss: 1.1890 - val_saturation_output_loss: 0.6330 - val_rotation_output_accuracy: 0.4673 - val_saturation_output_accuracy: 0.7116
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 15/100
# 275/275 [==============================] - 228s 830ms/step - loss: 0.8854 - rotation_output_loss: 1.1582 - saturation_output_loss: 0.6127 - rotation_output_accuracy: 0.4926 - saturation_output_accuracy: 0.7196 - val_loss: 0.9116 - val_rotation_output_loss: 1.1837 - val_saturation_output_loss: 0.6396 - val_rotation_output_accuracy: 0.4713 - val_saturation_output_accuracy: 0.7073
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 16/100
# 275/275 [==============================] - 228s 832ms/step - loss: 0.8724 - rotation_output_loss: 1.1453 - saturation_output_loss: 0.5994 - rotation_output_accuracy: 0.5026 - saturation_output_accuracy: 0.7242 - val_loss: 0.9401 - val_rotation_output_loss: 1.1983 - val_saturation_output_loss: 0.6819 - val_rotation_output_accuracy: 0.4650 - val_saturation_output_accuracy: 0.6886
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 17/100
# 275/275 [==============================] - 228s 832ms/step - loss: 0.8633 - rotation_output_loss: 1.1350 - saturation_output_loss: 0.5916 - rotation_output_accuracy: 0.5060 - saturation_output_accuracy: 0.7293 - val_loss: 0.9176 - val_rotation_output_loss: 1.1879 - val_saturation_output_loss: 0.6473 - val_rotation_output_accuracy: 0.4683 - val_saturation_output_accuracy: 0.6994
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 18/100
# 275/275 [==============================] - 228s 831ms/step - loss: 0.8513 - rotation_output_loss: 1.1200 - saturation_output_loss: 0.5827 - rotation_output_accuracy: 0.5157 - saturation_output_accuracy: 0.7332 - val_loss: 0.9110 - val_rotation_output_loss: 1.1853 - val_saturation_output_loss: 0.6367 - val_rotation_output_accuracy: 0.4699 - val_saturation_output_accuracy: 0.7045
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 19/100
# 275/275 [==============================] - 228s 829ms/step - loss: 0.8395 - rotation_output_loss: 1.1070 - saturation_output_loss: 0.5720 - rotation_output_accuracy: 0.5231 - saturation_output_accuracy: 0.7396 - val_loss: 0.9199 - val_rotation_output_loss: 1.1684 - val_saturation_output_loss: 0.6713 - val_rotation_output_accuracy: 0.4831 - val_saturation_output_accuracy: 0.6894
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 20/100
# 275/275 [==============================] - 227s 827ms/step - loss: 0.8271 - rotation_output_loss: 1.0912 - saturation_output_loss: 0.5629 - rotation_output_accuracy: 0.5333 - saturation_output_accuracy: 0.7456 - val_loss: 0.9131 - val_rotation_output_loss: 1.1882 - val_saturation_output_loss: 0.6379 - val_rotation_output_accuracy: 0.4738 - val_saturation_output_accuracy: 0.7069
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 21/100
# 275/275 [==============================] - 228s 830ms/step - loss: 0.8148 - rotation_output_loss: 1.0751 - saturation_output_loss: 0.5545 - rotation_output_accuracy: 0.5435 - saturation_output_accuracy: 0.7497 - val_loss: 0.9282 - val_rotation_output_loss: 1.1799 - val_saturation_output_loss: 0.6764 - val_rotation_output_accuracy: 0.4754 - val_saturation_output_accuracy: 0.6900
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 22/100
# 275/275 [==============================] - 227s 826ms/step - loss: 0.8040 - rotation_output_loss: 1.0603 - saturation_output_loss: 0.5477 - rotation_output_accuracy: 0.5490 - saturation_output_accuracy: 0.7512 - val_loss: 0.9148 - val_rotation_output_loss: 1.1881 - val_saturation_output_loss: 0.6416 - val_rotation_output_accuracy: 0.4740 - val_saturation_output_accuracy: 0.7071
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 23/100
# 275/275 [==============================] - 228s 831ms/step - loss: 0.7882 - rotation_output_loss: 1.0384 - saturation_output_loss: 0.5380 - rotation_output_accuracy: 0.5634 - saturation_output_accuracy: 0.7567 - val_loss: 0.9062 - val_rotation_output_loss: 1.1938 - val_saturation_output_loss: 0.6186 - val_rotation_output_accuracy: 0.4747 - val_saturation_output_accuracy: 0.7146
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 24/100
# 275/275 [==============================] - 228s 831ms/step - loss: 0.7739 - rotation_output_loss: 1.0178 - saturation_output_loss: 0.5300 - rotation_output_accuracy: 0.5741 - saturation_output_accuracy: 0.7613 - val_loss: 0.8939 - val_rotation_output_loss: 1.1809 - val_saturation_output_loss: 0.6068 - val_rotation_output_accuracy: 0.4814 - val_saturation_output_accuracy: 0.7247
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 25/100
# 275/275 [==============================] - 228s 831ms/step - loss: 0.7590 - rotation_output_loss: 0.9977 - saturation_output_loss: 0.5203 - rotation_output_accuracy: 0.5855 - saturation_output_accuracy: 0.7670 - val_loss: 0.8993 - val_rotation_output_loss: 1.1760 - val_saturation_output_loss: 0.6227 - val_rotation_output_accuracy: 0.4885 - val_saturation_output_accuracy: 0.7171
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 26/100
# 275/275 [==============================] - 229s 832ms/step - loss: 0.7411 - rotation_output_loss: 0.9743 - saturation_output_loss: 0.5080 - rotation_output_accuracy: 0.5989 - saturation_output_accuracy: 0.7719 - val_loss: 0.8928 - val_rotation_output_loss: 1.1742 - val_saturation_output_loss: 0.6113 - val_rotation_output_accuracy: 0.4921 - val_saturation_output_accuracy: 0.7213
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 27/100
# 275/275 [==============================] - 229s 833ms/step - loss: 0.7245 - rotation_output_loss: 0.9504 - saturation_output_loss: 0.4986 - rotation_output_accuracy: 0.6110 - saturation_output_accuracy: 0.7773 - val_loss: 0.8978 - val_rotation_output_loss: 1.1855 - val_saturation_output_loss: 0.6101 - val_rotation_output_accuracy: 0.4897 - val_saturation_output_accuracy: 0.7184
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 28/100
# 275/275 [==============================] - 228s 832ms/step - loss: 0.7046 - rotation_output_loss: 0.9224 - saturation_output_loss: 0.4869 - rotation_output_accuracy: 0.6251 - saturation_output_accuracy: 0.7846 - val_loss: 0.9077 - val_rotation_output_loss: 1.1968 - val_saturation_output_loss: 0.6185 - val_rotation_output_accuracy: 0.4848 - val_saturation_output_accuracy: 0.7147
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 29/100
# 275/275 [==============================] - 229s 834ms/step - loss: 0.6860 - rotation_output_loss: 0.8965 - saturation_output_loss: 0.4754 - rotation_output_accuracy: 0.6397 - saturation_output_accuracy: 0.7893 - val_loss: 0.9084 - val_rotation_output_loss: 1.1902 - val_saturation_output_loss: 0.6266 - val_rotation_output_accuracy: 0.4912 - val_saturation_output_accuracy: 0.7119
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 30/100
# 275/275 [==============================] - 229s 834ms/step - loss: 0.6683 - rotation_output_loss: 0.8702 - saturation_output_loss: 0.4664 - rotation_output_accuracy: 0.6520 - saturation_output_accuracy: 0.7938 - val_loss: 0.9437 - val_rotation_output_loss: 1.2382 - val_saturation_output_loss: 0.6492 - val_rotation_output_accuracy: 0.4763 - val_saturation_output_accuracy: 0.7042
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 31/100
# 275/275 [==============================] - 228s 829ms/step - loss: 0.6474 - rotation_output_loss: 0.8385 - saturation_output_loss: 0.4564 - rotation_output_accuracy: 0.6663 - saturation_output_accuracy: 0.8002 - val_loss: 0.9599 - val_rotation_output_loss: 1.2100 - val_saturation_output_loss: 0.7098 - val_rotation_output_accuracy: 0.4888 - val_saturation_output_accuracy: 0.6808
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 32/100
# 275/275 [==============================] - 228s 828ms/step - loss: 0.6268 - rotation_output_loss: 0.8067 - saturation_output_loss: 0.4468 - rotation_output_accuracy: 0.6832 - saturation_output_accuracy: 0.8041 - val_loss: 0.9257 - val_rotation_output_loss: 1.2097 - val_saturation_output_loss: 0.6417 - val_rotation_output_accuracy: 0.4921 - val_saturation_output_accuracy: 0.7089
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 33/100
# 275/275 [==============================] - 227s 827ms/step - loss: 0.6023 - rotation_output_loss: 0.7722 - saturation_output_loss: 0.4325 - rotation_output_accuracy: 0.7002 - saturation_output_accuracy: 0.8127 - val_loss: 0.9548 - val_rotation_output_loss: 1.2328 - val_saturation_output_loss: 0.6768 - val_rotation_output_accuracy: 0.4886 - val_saturation_output_accuracy: 0.6953
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 34/100
# 275/275 [==============================] - 228s 829ms/step - loss: 0.5785 - rotation_output_loss: 0.7365 - saturation_output_loss: 0.4204 - rotation_output_accuracy: 0.7160 - saturation_output_accuracy: 0.8204 - val_loss: 0.9550 - val_rotation_output_loss: 1.2476 - val_saturation_output_loss: 0.6625 - val_rotation_output_accuracy: 0.4903 - val_saturation_output_accuracy: 0.7030
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 35/100
# 275/275 [==============================] - 229s 833ms/step - loss: 0.5575 - rotation_output_loss: 0.7042 - saturation_output_loss: 0.4109 - rotation_output_accuracy: 0.7321 - saturation_output_accuracy: 0.8255 - val_loss: 0.9774 - val_rotation_output_loss: 1.2554 - val_saturation_output_loss: 0.6994 - val_rotation_output_accuracy: 0.4905 - val_saturation_output_accuracy: 0.6935
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets
# Epoch 36/100
# 275/275 [==============================] - 229s 833ms/step - loss: 0.5309 - rotation_output_loss: 0.6646 - saturation_output_loss: 0.3973 - rotation_output_accuracy: 0.7500 - saturation_output_accuracy: 0.8329 - val_loss: 0.9810 - val_rotation_output_loss: 1.2965 - val_saturation_output_loss: 0.6655 - val_rotation_output_accuracy: 0.4875 - val_saturation_output_accuracy: 0.7038
# INFO:tensorflow:Assets written to: p_model_checkpoint/assets

# %%
def plot_metric(metric):
  plt.clf()
  fig = go.Figure()
  fig.add_trace(go.Scatter(
                      y=history.history[metric],
                      name='Train'))
  fig.add_trace(go.Scatter(
                      y=history.history['val_'+metric],
                      name='Valid'))
  fig.update_layout(height=500, 
                    width=700,
                    title=metric,
                    xaxis_title='Epoch',
                    yaxis_title='Accuracy/Loss')
  fig.show()

metrics = ['rotation_output_accuracy', 'rotation_output_loss', 'saturation_output_accuracy', 'saturation_output_loss', 'loss']
for i in metrics:
  plot_metric(i)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1fa5a2bc-8deb-444e-a379-c6f7a54775ed" class="plotly-graph-div" style="height:500px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1fa5a2bc-8deb-444e-a379-c6f7a54775ed")) {
#                     Plotly.newPlot(
#                         '1fa5a2bc-8deb-444e-a379-c6f7a54775ed',
#                         [{"name": "Train", "type": "scatter", "y": [0.3283664882183075, 0.37042614817619324, 0.38859376311302185, 0.40019887685775757, 0.40911930799484253, 0.4218039810657501, 0.4305397868156433, 0.4395170509815216, 0.4479261338710785, 0.454176127910614, 0.4630255699157715, 0.47018465399742126, 0.4759517014026642, 0.4838068187236786, 0.4926278293132782, 0.5025568008422852, 0.5060369372367859, 0.5156960487365723, 0.5230540037155151, 0.5333380699157715, 0.5435085296630859, 0.5490198731422424, 0.5633664727210999, 0.5741050839424133, 0.5855113863945007, 0.5988920331001282, 0.6109943389892578, 0.6250852346420288, 0.6397017240524292, 0.6519744396209717, 0.6663352251052856, 0.6832102537155151, 0.7001988887786865, 0.7159942984580994, 0.7321164608001709, 0.7500284314155579]}, {"name": "Valid", "type": "scatter", "y": [0.28527113795280457, 0.4019990861415863, 0.41360294818878174, 0.4253791272640228, 0.4302619397640228, 0.42595359683036804, 0.43933823704719543, 0.4447380602359772, 0.44065946340560913, 0.4586397111415863, 0.4560546875, 0.4654756486415863, 0.46019071340560913, 0.46725642681121826, 0.4713350236415863, 0.46501609683036804, 0.4683478772640228, 0.46989890933036804, 0.4831112027168274, 0.47380515933036804, 0.47535616159439087, 0.4739774763584137, 0.4746668338775635, 0.4813878536224365, 0.48851102590560913, 0.49207261204719543, 0.4896599352359772, 0.4847771227359772, 0.4911534786224365, 0.4762752652168274, 0.48879826068878174, 0.4921300411224365, 0.4885684847831726, 0.49034926295280457, 0.4905216097831726, 0.48747703433036804]}],
#                         {"height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker":  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="650870ad-f501-4ccf-86d6-49edc5f3a3da" class="plotly-graph-div" style="height:500px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("650870ad-f501-4ccf-86d6-49edc5f3a3da")) {
#                     Plotly.newPlot(
#                         '650870ad-f501-4ccf-86d6-49edc5f3a3da',
#                         [{"name": "Train", "type": "scatter", "y": [1.4292527437210083, 1.3341670036315918, 1.3090308904647827, 1.2916802167892456, 1.2774571180343628, 1.259528636932373, 1.2487618923187256, 1.2350475788116455, 1.2251585721969604, 1.2120249271392822, 1.203331470489502, 1.1918346881866455, 1.182443618774414, 1.1696025133132935, 1.1582380533218384, 1.1453039646148682, 1.1349784135818481, 1.1199805736541748, 1.1070476770401, 1.0911895036697388, 1.0751490592956543, 1.0602537393569946, 1.0383563041687012, 1.017815351486206, 0.9976795315742493, 0.974268913269043, 0.9503938555717468, 0.9224144816398621, 0.8965064883232117, 0.8702144026756287, 0.8385284543037415, 0.806749165058136, 0.7721503376960754, 0.7365036010742188, 0.7042339444160461, 0.6645563840866089]}, {"name": "Valid", "type": "scatter", "y": [1.384041666984558, 1.351474404335022, 1.274287223815918, 1.2554210424423218, 1.2430307865142822, 1.2395039796829224, 1.2271339893341064, 1.2220125198364258, 1.2246360778808594, 1.2045457363128662, 1.2065155506134033, 1.1953686475753784, 1.1975990533828735, 1.1889543533325195, 1.1837024688720703, 1.198293924331665, 1.1878734827041626, 1.185301423072815, 1.1683870553970337, 1.1882219314575195, 1.1799288988113403, 1.1880550384521484, 1.1938090324401855, 1.1809415817260742, 1.1759740114212036, 1.1742151975631714, 1.1854989528656006, 1.196825623512268, 1.1901922225952148, 1.2381582260131836, 1.2099885940551758, 1.2097368240356445, 1.2327690124511719, 1.2475515604019165, 1.2553647756576538, 1.2965269088745117]}],
#                         {"height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker":  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b49ed50a-ae00-457b-aea5-37bbdbb57555" class="plotly-graph-div" style="height:500px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b49ed50a-ae00-457b-aea5-37bbdbb57555")) {
#                     Plotly.newPlot(
#                         'b49ed50a-ae00-457b-aea5-37bbdbb57555',
#                         [{"name": "Train", "type": "scatter", "y": [0.3591335117816925, 0.49120739102363586, 0.5679829716682434, 0.6106675863265991, 0.6372443437576294, 0.6537641882896423, 0.6682812571525574, 0.6774432063102722, 0.6866477131843567, 0.6927130818367004, 0.7022727131843567, 0.7047869563102722, 0.7125142216682434, 0.716107964515686, 0.7196306586265564, 0.724190354347229, 0.7293323874473572, 0.7332102060317993, 0.7395880818367004, 0.7455681562423706, 0.7496874928474426, 0.7512074112892151, 0.7566761374473572, 0.7613494396209717, 0.7669886350631714, 0.7719176411628723, 0.7772727012634277, 0.7845880389213562, 0.7892897725105286, 0.7938352227210999, 0.8001704812049866, 0.8041192889213562, 0.8126704692840576, 0.8204261660575867, 0.825539767742157, 0.8329119086265564]}, {"name": "Valid", "type": "scatter", "y": [0.318359375, 0.4713350236415863, 0.6143152713775635, 0.6324104070663452, 0.6557904481887817, 0.6704963445663452, 0.6738855838775635, 0.688361644744873, 0.6882467865943909, 0.692267894744873, 0.7035845518112183, 0.7062270045280457, 0.7028377652168274, 0.7116268277168274, 0.7072610259056091, 0.6886488795280457, 0.6994485259056091, 0.7045036554336548, 0.6893956661224365, 0.706916332244873, 0.6900275945663452, 0.707146167755127, 0.7146139740943909, 0.7246668338775635, 0.7171415686607361, 0.7213349938392639, 0.7184053063392639, 0.7146714329719543, 0.7118566036224365, 0.704216480255127, 0.680778980255127, 0.7089269161224365, 0.6953125, 0.7029526829719543, 0.693474292755127, 0.7037568688392639]}],
#                         {"height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker":  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="10e8f26a-e09c-4fcc-8479-f5b6d9196ff4" class="plotly-graph-div" style="height:500px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("10e8f26a-e09c-4fcc-8479-f5b6d9196ff4")) {
#                     Plotly.newPlot(
#                         '10e8f26a-e09c-4fcc-8479-f5b6d9196ff4',
#                         [{"name": "Train", "type": "scatter", "y": [1.3524609804153442, 1.0921863317489624, 0.9525941014289856, 0.857559859752655, 0.7968513369560242, 0.7575792670249939, 0.7281339764595032, 0.7046911120414734, 0.6845422983169556, 0.6705785989761353, 0.6536036729812622, 0.6442075371742249, 0.630673348903656, 0.6207136511802673, 0.6126541495323181, 0.5994340181350708, 0.5915989279747009, 0.5826933979988098, 0.5719624757766724, 0.5629175305366516, 0.5544760823249817, 0.5477245450019836, 0.5380343198776245, 0.5300167202949524, 0.5203371644020081, 0.508009672164917, 0.49858981370925903, 0.48685285449028015, 0.47542640566825867, 0.4663555920124054, 0.45635849237442017, 0.4468417167663574, 0.4324752986431122, 0.42043715715408325, 0.41085928678512573, 0.39730051159858704]}, {"name": "Valid", "type": "scatter", "y": [1.377598762512207, 1.2102131843566895, 0.877835750579834, 0.798318088054657, 0.7544307708740234, 0.7229440808296204, 0.7156058549880981, 0.6814175844192505, 0.6824803352355957, 0.6734300851821899, 0.6493028402328491, 0.6449202299118042, 0.6522161364555359, 0.6329656839370728, 0.6395694017410278, 0.6818986535072327, 0.6472921371459961, 0.6366792917251587, 0.6713466048240662, 0.6379004120826721, 0.676398754119873, 0.6416305303573608, 0.6186020970344543, 0.6068354249000549, 0.6226902008056641, 0.6113125085830688, 0.610089123249054, 0.618524968624115, 0.6265764832496643, 0.649238109588623, 0.7097638845443726, 0.641654908657074, 0.6768324971199036, 0.6625099778175354, 0.6993702054023743, 0.665523886680603]}],
#                         {"height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker":  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0800ca19-be06-46bf-aabb-11af4e0ef838" class="plotly-graph-div" style="height:500px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0800ca19-be06-46bf-aabb-11af4e0ef838")) {
#                     Plotly.newPlot(
#                         '0800ca19-be06-46bf-aabb-11af4e0ef838',
#                         [{"name": "Train", "type": "scatter", "y": [1.3908571004867554, 1.213176965713501, 1.1308120489120483, 1.0746203660964966, 1.0371538400650024, 1.0085538625717163, 0.9884477257728577, 0.9698694944381714, 0.9548507332801819, 0.9413022398948669, 0.9284674525260925, 0.9180213809013367, 0.9065584540367126, 0.8951581120491028, 0.8854461908340454, 0.8723690509796143, 0.8632883429527283, 0.8513370156288147, 0.8395052552223206, 0.827053427696228, 0.8148126602172852, 0.8039883971214294, 0.788195788860321, 0.7739160060882568, 0.7590083479881287, 0.741138756275177, 0.7244917154312134, 0.7046335339546204, 0.6859661936759949, 0.6682850122451782, 0.6474435329437256, 0.6267955303192139, 0.602312445640564, 0.5784706473350525, 0.5575465559959412, 0.5309286117553711]}, {"name": "Valid", "type": "scatter", "y": [1.3808202743530273, 1.28084397315979, 1.076061487197876, 1.026869773864746, 0.9987308382987976, 0.9812242984771729, 0.9713696837425232, 0.9517151117324829, 0.953558087348938, 0.9389879107475281, 0.9279091954231262, 0.9201446771621704, 0.9249076247215271, 0.9109601378440857, 0.9116361141204834, 0.940096378326416, 0.917582631111145, 0.9109902381896973, 0.9198670387268066, 0.9130610823631287, 0.9281635880470276, 0.9148426055908203, 0.9062053561210632, 0.8938887715339661, 0.8993321657180786, 0.8927639126777649, 0.8977939486503601, 0.9076752066612244, 0.9083842039108276, 0.9436981081962585, 0.9598762392997742, 0.9256958961486816, 0.9548006653785706, 0.9550309777259827, 0.977367639541626, 0.9810255765914917]}],
#                         {"height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker":  ...

# %%
test_batch_size = 128
test_generator = data_generator.generate_images(test_idx, is_training=False, batch_size=test_batch_size)
rotation_pred, sharpness_pred= p_model.predict(test_generator, steps=len(test_idx)//test_batch_size)

# %%
test_generator = data_generator.generate_images(test_idx, is_training=False, batch_size=test_batch_size)
samples = 0
images, rotation_true, sharpness_true = [], [], []
for test_batch in test_generator:
    image = test_batch[0]
    labels = test_batch[1]
    
    images.extend(image)
    rotation_true.extend(labels[0])
    sharpness_true.extend(labels[1])
    
rotation_true = np.array(rotation_true)
sharpness_true = np.array(sharpness_true)
rotation_true, sharpness_true = rotation_true.argmax(axis=-1), sharpness_true.argmax(axis=-1)
rotation_pred, sharpness_pred = rotation_pred.argmax(axis=-1), sharpness_pred.argmax(axis=-1)

# %%
cr_rotation = classification_report(rotation_true, rotation_pred, target_names=dataset_dict['rotation_alias'].keys())
print(cr_rotation)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.58      0.51      5532
#           90       0.55      0.40      0.46      5390
#          180       0.46      0.56      0.50      5547
#          270       0.54      0.43      0.48      5419
#
#     accuracy                           0.49     21888
#    macro avg       0.50      0.49      0.49     21888
# weighted avg       0.50      0.49      0.49     21888

# %%
cr_sharpness = classification_report(sharpness_true, sharpness_pred, target_names=dataset_dict['sat_alias'].keys())
print(cr_sharpness)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95      5548
#         0.25       0.83      0.81      0.82      5567
#         0.75       0.52      0.65      0.58      5465
#            1       0.68      0.45      0.54      5308
#
#     accuracy                           0.73     21888
#    macro avg       0.73      0.73      0.72     21888
# weighted avg       0.74      0.73      0.73     21888

# %%
## Ref: https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly.
class createAugment(keras.utils.Sequence):
  'Generates data for Keras'
  def __init__(self, X, y, batch_size=128, dim=(64, 64), n_channels=3, shuffle=True):
      'Initialization'
      self.batch_size = batch_size 
      self.X = X 
      self.y = y
      self.dim = dim
      self.n_channels = n_channels
      self.shuffle = shuffle
      
      self.on_epoch_end()

  def __len__(self):
      'Denotes the number of batches per epoch'
      return int(np.floor(len(self.X) / self.batch_size))

  def __getitem__(self, index):
      'Generate one batch of data'
      # Generate indexes of the batch
      indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

      # Generate data
      return self.__data_generation(indexes)

  def on_epoch_end(self):
      'Updates indexes after each epoch'
      self.indexes = np.arange(len(self.X))
      if self.shuffle:
          np.random.shuffle(self.indexes)

  def __data_generation(self, idxs):
    # X_batch is a matrix of masked images used as input
    X_batch = np.empty((self.batch_size, self.dim[0], self.dim[1], self.n_channels)) # Masked image
    # y_batch is a matrix of original images used for computing error from reconstructed image
    y_batch = np.empty((self.batch_size, self.dim[0], self.dim[1], self.n_channels)) # Original image

    ## Iterate through random indexes
    for i, idx in enumerate(idxs):
      image_copy = self.X[idx].copy()
  
      ## Get mask associated to that image
      masked_image = self.__createMask(image_copy)
      
      X_batch[i,] = masked_image/255
      y_batch[i] = self.y[idx]/255
      
    return X_batch, y_batch

  def __createMask(self, img):
    ## Prepare masking matrix
    mask = np.full((64,64,3), 255, np.uint8)
    for _ in range(np.random.randint(1, 10)):
      # Get random x locations to start line
      x1, x2 = np.random.randint(1, 64), np.random.randint(1, 64)
      # Get random y locations to start line
      y1, y2 = np.random.randint(1, 64), np.random.randint(1, 64)
      # Get random thickness of the line drawn
      thickness = np.random.randint(1, 7)
      # Draw black line on the white mask
      cv2.line(mask,(x1,y1),(x2,y2),(1,1,1),thickness)

    # Perforn bitwise and operation to mak the image
    masked_image = cv2.bitwise_and(img, mask)

    return masked_image

# %%
x_train, y_train, x_test, y_test = get_data(get_id_dictionary())
# Out:
# starting loading data
# finished loading data, in 17.324546575546265 seconds

# %%
print(len(x_train))
print(len(x_test))
# Out:
# 100000
# 10000

# %%
## Prepare training and testing mask-image pair generator
d_train_gen = createAugment(x_train, x_train, batch_size=256)
d_test_gen = createAugment(x_test, x_test, shuffle=False, batch_size=256)

# %%
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
## Examples
sample_idx = 90 ## Change this to see different batches

sample_masks, sample_labels = d_train_gen[sample_idx]
sample_images = [None]*(len(sample_masks)+len(sample_labels))
sample_images[::2] = sample_labels
sample_images[1::2] = sample_masks

fig = plt.figure(figsize=(16., 8.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(4, 8),  # creates 2x2 grid of axes
                 axes_pad=0.3,  # pad between axes in inch.
                 )

for ax, image in zip(grid, sample_images):
  ax.imshow(image)

plt.show()

# %%
## For more information into formulation: https://www.youtube.com/watch?v=AZr64OxshLo
## Metric
def dice_coef(y_true, y_pred):
    y_true_f = keras.backend.flatten(y_true)
    y_pred_f = keras.backend.flatten(y_pred)
    intersection = keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection) / (keras.backend.sum(y_true_f + y_pred_f))

def dice_loss(y_true, y_pred):
  return 1 - dice_coef(y_true, y_pred)

def ssim_loss(y_true, y_pred):
  y_true_f = keras.backend.flatten(y_true)
  y_pred_f = keras.backend.flatten(y_pred)
  return 1 - SSIM(y_true_f, y_pred_f, multichannel=True)

def ssim_coef(y_true, y_pred):
  return 1 - SSIM(y_true, y_pred, multichannel=True)

# %%
keras.backend.clear_session()
d_model = inpaintingModel().prepare_model()
depth = 16
  # d_model.layers[:depth]:
  # print(i)
  # layer.set_weights(p_model.layers)
  # d_model.trainable_weights[i].assign(p_model.trainable_weights[i])
for i in range(depth):
  d_model.layers[i].set_weights(p_model.layers[i].get_weights())
  d_model.layers[i].trainable = False
d_model.compile(optimizer='adam', loss= 'mean_absolute_error', metrics=[dice_coef])

keras.utils.plot_model(d_model, show_shapes=True, dpi=76, to_file='d_model_v1.png')

# %%
d_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 256)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 512)    2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 1024)   4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 1024)   9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 1024)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 2, 2, 2048)   18876416    max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 2, 2, 2048)   37750784    conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 4, 4, 1024)   8389632     conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 4, 2048)   0           conv2d_transpose[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 1024)   18875392    concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 1024)   9438208     conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 8, 8, 512)    2097664     conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 1024)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 512)    4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 512)    2359808     conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 256)  524544      conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 512)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 128)  131200      conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_3[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 64)   32832       conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 3)    1731        conv2d_21[0][0]
# ==================================================================================================
# Total params: 124,363,843
# Trainable params: 105,520,643
# Non-trainable params: 18,843,200
# __________________________________________________________________________________________________

# %%
# d_model.layers[5].get_weights()

# %% [markdown]
# # Trying again
# ## IT WORKS !!!

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=1, restore_best_weights=True)
checkpoint = ModelCheckpoint("d_model_checkpoint", monitor='dice_coef')
batch_size = 256
valid_batch_size = 256
downstream_epochs = 4
# train_gen = data_generator.generate_images(train_idx, is_training=True, batch_size=batch_size)
# valid_gen = data_generator.generate_images(valid_idx, is_training=True, batch_size=valid_batch_size)
callbacks = [early_stopping, checkpoint]
d_history = d_model.fit(d_train_gen,
                    # steps_per_epoch=len(d_train_gen)//batch_size,
                    epochs=downstream_epochs,
                    callbacks=callbacks,
                    # validation_split = 0.25
                    validation_data=d_test_gen,
                    # validation_steps = len(d_test_gen)//batch_size
                    )
                    # class_weight=dict(
                    #     rotation_output = rots_dict,
                    #     sharpness_output = sharps_dict
                    # ), 
                    # use_multiprocessing=True,
                    # validation_data=valid_gen,
                    # validation_steps=len(valid_idx)//valid_batch_size)

# %%
from skimage.metrics import structural_similarity as SSIM
from skimage.metrics import peak_signal_noise_ratio as PSNR

# %%
## Examples
rows = 64
sample_idx = 45
sample_images, sample_labels = d_test_gen[sample_idx]

fig, axs = plt.subplots(nrows=rows, ncols=3, figsize=(6, 2*rows))
mean_psnr = 0.0
mean_ssim = 0.0
for i in range(rows):
  impainted_image = d_model.predict(sample_images[i].reshape((1,)+sample_images[i].shape))
  axs[i][0].imshow(sample_labels[i])
  axs[i][1].imshow(sample_images[i])
  axs[i][2].imshow(impainted_image.reshape(impainted_image.shape[1:]))
  mean_psnr += PSNR(sample_labels[i],impainted_image.reshape(impainted_image.shape[1:]))
  mean_ssim += SSIM(sample_labels[i],impainted_image.reshape(impainted_image.shape[1:]), multichannel=True)


plt.show()
print(f"Mean PSNR value = {mean_psnr/rows}")
print(f"Mean SSIM value = {mean_ssim/rows}")

# %% [markdown]
# Fully supervised is 0.96 on cifar-10 (30 epochs) but yayy 0.85+ in just 2 epochs !!

# %%
print(d_history.history)

# %%
plt.clf()
fig = go.Figure()
fig.add_trace(go.Scatter(
                    y=d_history.history['loss'],
                    name='Train'))
fig.add_trace(go.Scatter(
                    y=d_history.history['val_loss'],
                    name='Valid'))
fig.update_layout(height=500, 
                  width=700,
                  title='Loss for image inpainting',
                  xaxis_title='Epoch',
                  yaxis_title='Loss')
fig.show()

# %%
preprocess_input = keras.applications.xception.preprocess_input

# %% [markdown]
# GRad cam code below

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
import matplotlib.cm as cm
img_size = (64, 64, 3)
last_conv_layer_name = "conv2d_22"

# The local path to our target image
# img_path = 'add/image/path/here'

# Prepare image
# img = sample_images[0]
# np.reshape(img, (None,img.shape))
img_array = preprocess_input(get_img_array(img_path, size=img_size))
# Make model
model = d_model

# Remove last layer's softmax
model.layers[-1].activation = None
# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])
# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))


save_and_display_gradcam(img_path, heatmap)

# %%
sample_labels[0]

# %%
cv2_imshow(sample_labels[0]*255)

# %%
# !pip install keract

# %%
import keract

# %%
activations = keract.get_activations(d_model, sample_labels[:1], auto_compile=True)

# %%
keract.display_activations(activations, cmap=None, save=False, directory='.', data_format='channels_last', fig_size=(64, 64), reshape_1d_layers=False)
